# %% [markdown]
# Bruge til visualisering af ekesempel grafen og and små test

# %%
from Matrix_graph import ws_opinion_graph, create_matrix_rep, GraphState, add_media_nodes,add_disinfo_nodes,state_to_graph, er_opinion_graph
from Matrix_simuleringslogik import time_step_no_media_no_disinfo, simpel_simulering, data_processing,in_and_out_degree_sum,cross_type_degree
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
from Graf import illustration_of_graph

# %%
matrix = ws_opinion_graph(5,2,0.1)

# %%
DD = create_matrix_rep(matrix)

# %%
nx.draw(matrix, with_labels=True)
plt.show()

illustration_of_graph(matrix)

# %%
print(DD.matrix[0].sum())
# Out:
# 0.924902629016553
